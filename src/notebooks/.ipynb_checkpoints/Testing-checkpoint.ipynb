# %%
import sys
sys.path.insert(0, "../autowrite")

# %%
from Iamondb import Iamondb
from Visualizer import Visualizer

# %%
iamondb = Iamondb("./../../data/raw_data")

# %%
samples = iamondb.get_samples()

# %%
print(len(samples[0]), len(samples[0]))
# Out:
# 11983 11983

# %%
sample = samples[0][0]
sample_text = samples[1][0]

# %%
visualizer = Visualizer()

# %%
visualizer.plot_raw_sample(sample)
print(sample_text)
# Out:
# But no! She ai nt got sense

# %%
from Preprocessor import Preprocessor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 from Preprocessor import Preprocessor
#
# ImportError: cannot import name 'Preprocessor' from 'Preprocessor' (/home/jakob.j.jeep/AutoWrite/src/notebooks/../autowrite/Preprocessor.py)

# %%
preprocessor = Preprocessor()

# %%
normalized_sample = preprocessor.normalize(sample)
